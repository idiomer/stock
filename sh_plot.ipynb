# %%
import pandas as pd
from pandas import DataFrame
import glob

# %%
df = DataFrame.from_csv('data/index/000001/2018.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2017.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2016.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2015.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2014.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2013.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2012.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2011.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2010.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2009.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2008.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2007.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2006.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2005.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2004.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2003.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2002.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2001.csv.gz')
df['close'].plot()

# %%
df = DataFrame.from_csv('data/index/000001/2000.csv.gz')
df['close'].plot()
